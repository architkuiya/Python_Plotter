# %%
from graphs import *
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

data = pd.read_csv("/home/jaskirats/Code/Python_Plotter_prev/Files/RELIANCE.csv")

sb.pairplot(data, markers="s")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.9/site-packages/matplotlib/markers.py in _set_marker(self, marker)
#     326             try:
# --> 327                 Path(marker)
#     328                 self._marker_function = self._set_vertices
#
# ~/.local/lib/python3.9/site-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     127         """
# --> 128         vertices = _to_unmasked_float_array(vertices)
#     129         _api.check_shape((None, 2), vertices=vertices)
#
# ~/.local/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1332     else:
# -> 1333         return np.asarray(x, float)
#    1334
#
# ValueError: could not convert string to float: '#'
#
# The above exception was the direct cause of the following exception:
#
# ...
